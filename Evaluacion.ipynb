# %%
import funciones as fs

# %%
df = fs.cargar_dataset("Victoria BC.csv")
df
#elimina la columna Unnamed: 0
df = df.drop('Unnamed: 0', axis=1)
df
#elimina la columa calendar_updated
df = df.drop('calendar_updated', axis=1)
df
# Out:
#                        id     scrape_id last_scraped  \
# 0                   19898  2.024120e+13     29/12/24
# 1                   41168  2.024120e+13     29/12/24
# 2                   83515  2.024120e+13     29/12/24
# 3                  168460  2.024120e+13     29/12/24
# 4                  185732  2.024120e+13     29/12/24
# ...                   ...           ...          ...
# 3946  1315368084757533488  2.024120e+13     29/12/24
# 3947  1316608634341666791  2.024120e+13     29/12/24
# 3948  1317141084646533661  2.024120e+13     29/12/24
# 3949  1318221712246054906  2.024120e+13     29/12/24
# 3950  1318259877390189592  2.024120e+13     29/12/24
#
#                                          host_url             host_location  \
# 0         https://www.airbnb.com/users/show/69729                       NaN
# 1        https://www.airbnb.com/users/show/173169          Victoria, Canada
# 2        https://www.airbnb.com/users/show/455118  British Columbia, Canada
# ...

# %%
df2 = fs.limpiar_valores_nulos(df)
df2
# Out:
#                        id     scrape_id last_scraped  \
# 0                   19898  2.024120e+13     29/12/24
# 1                   41168  2.024120e+13     29/12/24
# 2                   83515  2.024120e+13     29/12/24
# 3                  168460  2.024120e+13     29/12/24
# 4                  185732  2.024120e+13     29/12/24
# ...                   ...           ...          ...
# 3946  1315368084757533488  2.024120e+13     29/12/24
# 3947  1316608634341666791  2.024120e+13     29/12/24
# 3948  1317141084646533661  2.024120e+13     29/12/24
# 3949  1318221712246054906  2.024120e+13     29/12/24
# 3950  1318259877390189592  2.024120e+13     29/12/24
#
#                                          host_url             host_location  \
# 0         https://www.airbnb.com/users/show/69729     Este_es_un_valor_nulo
# 1        https://www.airbnb.com/users/show/173169          Victoria, Canada
# 2        https://www.airbnb.com/users/show/455118  British Columbia, Canada
# ...

# %%
fs.identificar_valores_nulos(df2)
# Out:
# (id                                              0
#  scrape_id                                       0
#  last_scraped                                    0
#  host_url                                        0
#  host_location                                   0
#  host_acceptance_rate                            0
#  host_is_superhost                               0
#  host_total_listings_count                       0
#  host_verifications                              0
#  longitude                                       0
#  property_type                                   0
#  bathrooms                                       0
#  bathrooms_text                                  0
#  bedrooms                                        0
#  beds                                            0
#  amenities                                       0
#  minimum_nights                                  0
#  maximum_nights                                  0
# ...

# %%
fs.limpiar_valores_atipicos(df2)
df2
# Out:
#                        id     scrape_id last_scraped  \
# 0                   19898  2.024120e+13     29/12/24
# 1                   41168  2.024120e+13     29/12/24
# 2                   83515  2.024120e+13     29/12/24
# 3                  168460  2.024120e+13     29/12/24
# 4                  185732  2.024120e+13     29/12/24
# ...                   ...           ...          ...
# 3946  1315368084757533488  2.024120e+13     29/12/24
# 3947  1316608634341666791  2.024120e+13     29/12/24
# 3948  1317141084646533661  2.024120e+13     29/12/24
# 3949  1318221712246054906  2.024120e+13     29/12/24
# 3950  1318259877390189592  2.024120e+13     29/12/24
#
#                                          host_url             host_location  \
# 0         https://www.airbnb.com/users/show/69729     Este_es_un_valor_nulo
# 1        https://www.airbnb.com/users/show/173169          Victoria, Canada
# 2        https://www.airbnb.com/users/show/455118  British Columbia, Canada
# ...

# %%
fs.identificar_valores_nulos(df2)
# Out:
# (id                                              0
#  scrape_id                                       0
#  last_scraped                                    0
#  host_url                                        0
#  host_location                                   0
#  host_acceptance_rate                            0
#  host_is_superhost                               0
#  host_total_listings_count                       0
#  host_verifications                              0
#  longitude                                       0
#  property_type                                   0
#  bathrooms                                       0
#  bathrooms_text                                  0
#  bedrooms                                        0
#  beds                                            0
#  amenities                                       0
#  minimum_nights                                  0
#  maximum_nights                                  0
# ...
